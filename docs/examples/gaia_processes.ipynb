# %% [markdown]
# # Gaia Data I/O and Processing Examples
#
# This document contains examples of Gaia's file I/O capabilities and geospatial processes.
#
# The original Python notebook is available in the Gaia source code under the docs/examples folder.

# %%
# Import required modules
from gaia.geo.geo_inputs import *
from gaia.geo.processes_vector import *
from gaia.geo.processes_raster import *
from gaia import formats
from sqlalchemy import Table, Column, Integer, String, MetaData, create_engine, select, text
from geoalchemy2 import Geometry
import json
import folium #for mapping
from folium.plugins import ImageOverlay

# %% [markdown]
# ## Data
#
# - Create VectorFileIO objects from files containing GeoJSON.
# - Create a FeatureIO object containing one point.
# - Create RasterFileIO objects from GeoTiff image files.

# %%
# Roads in Iraq
iraq_allroads = VectorFileIO(uri='../../tests/data/iraq_roads.geojson')

# Roads in Iraq where type = 'motorway'
iraq_roads_motorway = VectorFileIO(uri='../../tests/data/iraq_roads.geojson', 
                          filters=[('type','=','motorway')])

# Motorway A1
iraq_roads_a1 = VectorFileIO(uri='../../tests/data/iraq_roads.geojson', 
                          filters=[('ref','=','A1')])

# Bike paths in Iraq, i.e. roads where type = 'bikepath'; 
# use only a subset of available columns
iraq_bikepaths = VectorFileIO(uri='../../tests/data/iraq_roads.geojson', 
                              filters=[('type','=','bikepath')])

# Hospitals in Iraq
iraq_hospitals = VectorFileIO(uri='../../tests/data/iraq_hospitals.geojson', columns=['name'])

# Districts in Baghdad
baghdad_alldistricts = VectorFileIO(uri='../../tests/data/baghdad_districts.geojson')

# Districts in Baghdad where name starts with 'A'
baghdad_districts_a = VectorFileIO(uri='../../tests/data/baghdad_districts.geojson',
                                   filters=[('NNAME', 'startswith', 'A')])

# A single point
featureio = FeatureIO(features=[
        {"geometry": {"type": "Point", "coordinates": [44.43, 33.33]}, "properties":{}},
    ])

# Raster images
globaltemp = RasterFileIO(uri='../../tests/data/globalairtemp.tif')
globalprecip = RasterFileIO(uri='../../tests/data/globalprecip.tif')

# Raster images for multi-band merge.
satellite1 = RasterFileIO(uri='../../tests/data/satellite_test_data/LC81070352015218LGN00_B4.tif') 
satellite2 = RasterFileIO(uri='../../tests/data/satellite_test_data/LC81070352015218LGN00_B5.tif') 
satellite3 = RasterFileIO(uri='../../tests/data/satellite_test_data/LC81070352015218LGN00_BQA.tif')

# %% [markdown]
# Verify that the 'iraq_bikepaths' IO object only contains records where type = 'bikepath'

# %%
iraq_bikepaths.read()
iraq_bikepaths.data
# Out:
#    bridge                                           geometry  maxspeed name  \
# 0       0  (LINESTRING (44.3087191 33.2924177, 44.3081596...         0
#
#    oneway   osm_id  ref  tunnel      type
# 0       1  4061247  A86       0  bikepath

# %% [markdown]
# Verify that the 'baghdad_districts_a' IO object only contains records where nname starts with 'A'

# %%
baghdad_districts_a.read()
baghdad_districts_a.data
# Out:
#     DID       DNAME  NID                            NNAME  \
# 5     3    7 Nissan   36  Al Husseinia, Maamal, Ar Rashad
# 21    1   Adhamiyah   14                        Adhamiyah
# 36    0      Rusafa    5                  Al Saadoom Park
# 40    0      Rusafa    3                        Abu Nuwas
# 45    6  Kadhimiyah   58              Ali Al-Saleh, Salam
# 55    5       Karkh   52              Al-Kindi, Harithiya
# 60    7     Mansour   69                        Al Amriya
# 67    7     Mansour   71                          Al-Adil
# 71    7     Mansour   67                        Al Yarmuk
# 73    7     Mansour   70         Al Khadhra'a, Al Jamia'a
# 78    8     Rasheed   83                         Al Furat
# 79    8     Rasheed   81                       Al Atiba'a
# 80    8     Rasheed   82      Ajnadin, Shurta 4, Shurta 5
# 86    4     Karadah   43                  Al Rasheed Camp
#
#                                              geometry  \
# 5   (POLYGON ((44.49221756429608 33.33403908470888...
# 21  (POLYGON ((44.37900477493537 33.35405573255764...
# 36  (POLYGON ((44.42613457929622 33.31509845782546...
# 40  (POLYGON ((44.423609555079 33.31177762337143, ...
# 45  (POLYGON ((44.32730297460603 33.34064005941366...
# 55  (POLYGON ((44.39937146502945 33.30226725093627...
# 60  (POLYGON ((44.31444838250417 33.30895203324138...
# 67  (POLYGON ((44.32471865292229 33.3297944594068,...
# 71  (POLYGON ((44.32310345187011 33.29070310243293...
# 73  (POLYGON ((44.32940273597404 33.32739541078479...
# 78  (POLYGON ((44.28325053395997 33.25520372874627...
# 79  (POLYGON ((44.28325053395997 33.25520372874627...
# 80  (POLYGON ((44.3210036905021 33.2507025386268, ...
# 86  (POLYGON ((44.51821487827073 33.26326941664911...
#
#                           id
# 5    baghdad_neighborhoods.6
# 21  baghdad_neighborhoods.22
# 36  baghdad_neighborhoods.37
# 40  baghdad_neighborhoods.41
# 45  baghdad_neighborhoods.66
# 55  baghdad_neighborhoods.55
# 60  baghdad_neighborhoods.60
# 67  baghdad_neighborhoods.68
# 71  baghdad_neighborhoods.72
# 73  baghdad_neighborhoods.74
# 78  baghdad_neighborhoods.79
# 79  baghdad_neighborhoods.80
# 80  baghdad_neighborhoods.81
# 86  baghdad_neighborhoods.87

# %% [markdown]
# ## Area Process
#
# Calculate the area of districts in Baghdad.  The output will be in square meters.  Display first 5 records.

# %%
area_pr = AreaProcess(inputs=[baghdad_alldistricts])
area_pr.compute()
print area_pr.output.uri
area_pr.output.data[:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/ea9f9fd2-14f1-45b1-accf-337f7e249cd7/ea9f9fd2-14f1-45b1-accf-337f7e249cd7.json
#    DID      DNAME  NID                              NNAME  \
# 0    7    Mansour   74      Baghdad International Airport
# 1    4    Karadah   46                          Zafriniya
# 2    1  Adhamiyah   25                           Rashdiya
# 3    2     Thawra   28                        Thawra City
# 4    3   7 Nissan   33  Habibiyah, Dor Al-Umal, Baladiyat
#
#                                             geometry                       id  \
# 0  (POLYGON ((44.25416164813192 33.36238209600769...  baghdad_neighborhoods.1
# 1  (POLYGON ((44.51697757715969 33.23343163393921...  baghdad_neighborhoods.2
# 2  (POLYGON ((44.38008196547639 33.43048095703135...  baghdad_neighborhoods.3
# 3  (POLYGON ((44.460606439164 33.35860356319701, ...  baghdad_neighborhoods.4
# 4  (POLYGON ((44.46060643916433 33.35860356319682...  baghdad_neighborhoods.5
#
#            area
# 0  8.613726e+07
# 1  1.296147e+07
# 2  1.038663e+07
# 3  3.312065e+07
# 4  1.138407e+07

# %% [markdown]
# Load the above results from the saved output GeoJSON file and display the properties of the first record

# %%
with open(area_pr.output.uri, 'r') as infile:
    result_json = json.load(infile)
    for property in result_json['features'][0]['properties'].items():
        print '{}: {}'.format(property[0], property[1])
# Out:
# area: 86137256.6561
# DID: 7
# NID: 74
# DNAME: Mansour
# id: baghdad_neighborhoods.1
# NNAME: Baghdad International Airport

# %% [markdown]
# ## Length Process
#
# Calculate the lengths of roads in Iraq, and display the first 5 records.

# %%
length_pr = LengthProcess(inputs=[iraq_allroads])
length_pr.compute()
print length_pr.output.uri
length_pr.output.data[:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/24098504-be2b-4298-a055-5a078687ce79/24098504-be2b-4298-a055-5a078687ce79.json
#    bridge                                           geometry  maxspeed name  \
# 0       0  (LINESTRING (44.30871909999998 33.2924177, 44....         0
# 1       0  (LINESTRING (44.2976627 33.37263139999998, 44....         0
# 2       0  (LINESTRING (44.39326450000001 33.3601687, 44....         0
# 3       0  (LINESTRING (44.3933047 33.35987779999999, 44....         0
# 4       0  (LINESTRING (44.30015469999999 33.403856499999...         0
#
#    oneway   osm_id           ref  tunnel      type       length
# 0       1  4061247           A86       0  bikepath  4542.446040
# 1       1  4074629           A86       0  motorway  5745.322548
# 2       1  4074770  A86/N11/D383       0  motorway  1610.913903
# 3       1  4074779  A86/N11/D383       0  motorway  1092.254097
# 4       1  4076793            A1       0  motorway  1587.980294

# %% [markdown]
# ## BufferProcess
#
# Buffer the bikepath in Iraq by 1000 meters

# %%
buffer_pr = BufferProcess(inputs=[iraq_bikepaths], buffer_size = 1000)
buffer_pr.compute()
print buffer_pr.output.uri

iraq_map = folium.Map([33.2924177, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

bikepath = folium.features.GeoJson(iraq_bikepaths.data.to_json())
buffer = folium.features.GeoJson(buffer_pr.output.data.to_json())

iraq_map.add_children(bikepath)
iraq_map.add_children(buffer)
iraq_map
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/95b7f399-17b8-4f4f-97ca-277b68ee510d/95b7f399-17b8-4f4f-97ca-277b68ee510d.json
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Within Process
#
# Find hospitals in Iraq that are located inside Baghdad districts.

# %%
within_pr = WithinProcess(inputs=[iraq_hospitals, baghdad_alldistricts])
within_pr.compute()
print within_pr.output.uri
within_pr.output.data[:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/0f9067ca-4794-4145-a4d0-7ba08e8c202a/0f9067ca-4794-4145-a4d0-7ba08e8c202a.json
#     fid                       geometry  \
# 0    28  POINT (44.3781274 33.3451792)
# 9   165  POINT (44.3253978 33.3764162)
# 10  166   POINT (44.3243249 33.377993)
# 14  189  POINT (44.3562015 33.2550027)
# 18  215  POINT (44.3602695 33.3171287)
#
#                                                id  \
# 0   iraq_hospitals.fid-76c404c7_15254deab67_-7748
# 9   iraq_hospitals.fid-76c404c7_15254deab67_-773f
# 10  iraq_hospitals.fid-76c404c7_15254deab67_-773e
# 14  iraq_hospitals.fid-76c404c7_15254deab67_-773a
# 18  iraq_hospitals.fid-76c404c7_15254deab67_-7736
#
#                            name      osm_id            timestamp      type
# 0   جامعة بغداد -- كلية الطب آل    94298797  2012-07-20T11:15:39  hospital
# 9                                 997416381  2010-11-21T05:22:05  hospital
# 10                                997416382  2010-11-21T05:22:06  hospital
# 14       dental clinic dr.nadir  1037908152  2010-12-13T23:42:52  hospital
# 18  Iraqi Red Crescent Hospital  1167754844  2011-02-23T08:12:29  hospital

# %%
iraq_map = folium.Map([33.2924177, 44.30871909999998],
                  zoom_start=10,
                  tiles='cartodbpositron')

hospitals = folium.features.GeoJson(within_pr.output.data.to_json())
districts = folium.features.GeoJson(baghdad_alldistricts.data.to_json())

iraq_map.add_children(hospitals)
iraq_map.add_children(districts)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Nearby Process
#
# Find hospitals nearest to the bikepath, no more than 8km away.

# %%
nearby_pr = NearProcess(inputs=[iraq_hospitals, iraq_bikepaths], distance=8000)
nearby_pr.compute()
print nearby_pr.output.uri
nearby_pr.output.data
# Out:
# ---------------------------------------------------------------------------
# GaiaException                             Traceback (most recent call last)
# <ipython-input-11-a7e253fd07cf> in <module>()
# ----> 1 nearby_pr = NearProcess(inputs=[iraq_hospitals, iraq_bikepaths], distance=8000)
#       2 nearby_pr.compute()
#       3 print nearby_pr.output.uri
#       4 nearby_pr.output.data
#
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/gaia/geo/processes_vector.pyc in __init__(self, distance, **kwargs)
#     688
#     689     def __init__(self, distance=None, **kwargs):
# --> 690         super(NearProcess, self).__init__(**kwargs)
#     691         self.distance = distance
#     692         if not self.output:
#
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/gaia/gaia_process.pyc in __init__(self, inputs, output, parent, **kwargs)
#      49         for k, v in kwargs.items():
#      50             setattr(self, k, v)
# ---> 51         self.validate()
#      52
#      53     def test_arg_type(self, arg, arg_type):
#
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/gaia/gaia_process.pyc in validate(self)
#     105             arg, arg_type = item['name'], item['type']
#     106             if not hasattr(self, arg) or getattr(self, arg) is None:
# --> 107                 raise GaiaException('Missing required argument {}'.format(arg))
#     108             self.test_arg_type(arg, arg_type)
#     109             if 'options' in item and getattr(self, arg) not in item['options']:
#
# GaiaException: Missing required argument distance

# %%
iraq_map = folium.Map([33.2924177, 44.30871909999998],
                  zoom_start=11,
                  tiles='cartodbpositron')

hospitals = folium.features.GeoJson(nearby_pr.output.data.to_json())
bikepath = folium.features.GeoJson(iraq_bikepaths.data.to_json())

iraq_map.add_children(hospitals)
iraq_map.add_children(bikepath)
iraq_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-24a483d5a527> in <module>()
#       3                   tiles='cartodbpositron')
#       4
# ----> 5 hospitals = folium.features.GeoJson(nearby_pr.output.data.to_json())
#       6 bikepath = folium.features.GeoJson(iraq_bikepaths.data.to_json())
#       7
#
# NameError: name 'nearby_pr' is not defined

# %% [markdown]
# ## Distance Process
#
# Calculate distance from each hospital to the nearest road.

# %%
distance_pr = DistanceProcess(inputs=[iraq_hospitals, iraq_allroads])
distance_pr.compute()
print distance_pr.output.uri
distance_pr.output.data[0:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/cbbc26e0-95ca-4b86-82d8-6052dadd7cd9/cbbc26e0-95ca-4b86-82d8-6052dadd7cd9.json
#     fid                                     geometry  \
# 33  490          POINT (44.34352449999999 33.377348)
# 10  166  POINT (44.32432489999999 33.37799299999999)
# 34  491  POINT (44.34124539999999 33.37471619999999)
# 9   165  POINT (44.32539779999999 33.37641619999999)
# 35  492         POINT (44.3796559 33.36271089999999)
#
#                                                id                    name  \
# 33  iraq_hospitals.fid-76c404c7_15254deab67_-7727  Al Kazimiyah Pediatric
# 10  iraq_hospitals.fid-76c404c7_15254deab67_-773e
# 34  iraq_hospitals.fid-76c404c7_15254deab67_-7726            Al Kazimiyah
# 9   iraq_hospitals.fid-76c404c7_15254deab67_-773f
# 35  iraq_hospitals.fid-76c404c7_15254deab67_-7725
#
#         osm_id            timestamp      type     distance
# 33  2202187518  2013-03-14T19:47:59  hospital   563.388416
# 10   997416382  2010-11-21T05:22:06  hospital   855.158626
# 34  2202187519  2013-03-14T19:47:59  hospital   993.049032
# 9    997416381  2010-11-21T05:22:05  hospital  1058.219341
# 35  2202187574  2013-03-14T19:48:01  hospital  1115.128166

# %% [markdown]
# ## Intersects Process
#
# Find the districts that intersect the motorways.

# %%
intersects_pr = IntersectsProcess(inputs=[baghdad_alldistricts, iraq_roads_motorway])
intersects_pr.compute()
print intersects_pr.output.uri
intersects_pr.output.data[:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/e8a1143a-640e-4fa7-b06d-21ba2fb02578/e8a1143a-640e-4fa7-b06d-21ba2fb02578.json
#     DID      DNAME  NID              NNAME  \
# 17    0     Rusafa    7         Sheik Omar
# 19    1  Adhamiyah   17            Maghreb
# 20    1  Adhamiyah   20              Tunis
# 25    0     Rusafa   10       Mustansiriya
# 26    1  Adhamiyah   16  Waziriya-Industry
#
#                                              geometry  \
# 17  (POLYGON ((44.38829821861083 33.34871127880871...
# 19  (POLYGON ((44.38642591694281 33.39479094110987...
# 20  (POLYGON ((44.36199641275005 33.3915827325705,...
# 25  (POLYGON ((44.41320658451895 33.3491355477567,...
# 26  (POLYGON ((44.39382687626517 33.3590579756513,...
#
#                           id
# 17  baghdad_neighborhoods.18
# 19  baghdad_neighborhoods.20
# 20  baghdad_neighborhoods.21
# 25  baghdad_neighborhoods.26
# 26  baghdad_neighborhoods.27

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

linestyle = lambda x: {'color': 'red'}
districts = folium.features.GeoJson(intersects_pr.output.data.to_json())
motorways = folium.features.GeoJson(iraq_roads_motorway.data.to_json(), style_function=linestyle)

iraq_map.add_children(districts)
iraq_map.add_children(motorways)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Disjoint
#
# Find the districts that do not intersect the motorways.

# %%
disjoint_pr = DisjointProcess(inputs=[baghdad_alldistricts, iraq_roads_motorway])
disjoint_pr.compute()
disjoint_pr.output.data[:5]
# Out:
#    DID      DNAME  NID                              NNAME  \
# 0    7    Mansour   74      Baghdad International Airport
# 1    4    Karadah   46                          Zafriniya
# 2    1  Adhamiyah   25                           Rashdiya
# 3    2     Thawra   28                        Thawra City
# 4    3   7 Nissan   33  Habibiyah, Dor Al-Umal, Baladiyat
#
#                                             geometry                       id
# 0  (POLYGON ((44.25416164813191 33.36238209600771...  baghdad_neighborhoods.1
# 1  (POLYGON ((44.51697757715971 33.23343163393923...  baghdad_neighborhoods.2
# 2  (POLYGON ((44.38008196547639 33.43048095703136...  baghdad_neighborhoods.3
# 3  (POLYGON ((44.460606439164 33.35860356319699, ...  baghdad_neighborhoods.4
# 4  (POLYGON ((44.46060643916434 33.35860356319682...  baghdad_neighborhoods.5

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=11,
                  tiles='cartodbpositron')

linestyle = lambda x: {'color': 'red'}
districts = folium.features.GeoJson(disjoint_pr.output.data.to_json())
motorways = folium.features.GeoJson(iraq_roads_motorway.data.to_json(), style_function=linestyle)

iraq_map.add_children(districts)
iraq_map.add_children(motorways)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Crosses
#
# Find the districts that cross the motorways.
#
# Definition of 'cross': [the interior of a feature intersects the interior of another but does not contain it, and the dimension of the intersection is less than the dimension of the one or the other.](http://geopandas.org/reference.html#GeoSeries.crosses)

# %%
crosses_pr = CrossesProcess(inputs=[baghdad_alldistricts, iraq_roads_motorway])
crosses_pr.compute()
print crosses_pr.output.uri
crosses_pr.output.data[:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/4139316b-fca7-4816-8ed3-2060a23161a7/4139316b-fca7-4816-8ed3-2060a23161a7.json
#     DID      DNAME  NID              NNAME  \
# 17    0     Rusafa    7         Sheik Omar
# 19    1  Adhamiyah   17            Maghreb
# 20    1  Adhamiyah   20              Tunis
# 25    0     Rusafa   10       Mustansiriya
# 26    1  Adhamiyah   16  Waziriya-Industry
#
#                                              geometry  \
# 17  (POLYGON ((44.38829821861083 33.34871127880871...
# 19  (POLYGON ((44.38642591694281 33.39479094110987...
# 20  (POLYGON ((44.36199641275005 33.3915827325705,...
# 25  (POLYGON ((44.41320658451895 33.3491355477567,...
# 26  (POLYGON ((44.39382687626517 33.3590579756513,...
#
#                           id
# 17  baghdad_neighborhoods.18
# 19  baghdad_neighborhoods.20
# 20  baghdad_neighborhoods.21
# 25  baghdad_neighborhoods.26
# 26  baghdad_neighborhoods.27

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

linestyle = lambda x: {'color': 'red'}
districts = folium.features.GeoJson(crosses_pr.output.data.to_json())
motorways = folium.features.GeoJson(iraq_roads_motorway.data.to_json(), style_function=linestyle)

iraq_map.add_children(districts)
iraq_map.add_children(motorways)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Touches
#
# Find the motorways that touch edges with but do not overlap the bike path.

# %%
touches_pr = TouchesProcess(inputs=[iraq_roads_motorway, iraq_bikepaths])
touches_pr.compute()
print touches_pr.output.uri
touches_pr.output.data
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/b9b1ef9b-649b-47be-9f94-2d6602db6b9b/b9b1ef9b-649b-47be-9f94-2d6602db6b9b.json
#     bridge                                           geometry  maxspeed name  \
# 37       1  (LINESTRING (44.3005238 33.3256872, 44.3004093...         0
#
#     oneway     osm_id  ref  tunnel      type
# 37       1  224040659  A86       0  motorway

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

linestyle = lambda x: {'color': 'red'}
bikepaths = folium.features.GeoJson(iraq_bikepaths.data.to_json())
roads = folium.features.GeoJson(touches_pr.output.data.to_json(), style_function=linestyle)

iraq_map.add_children(bikepaths)
iraq_map.add_children(roads)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Union
#
# Create a dataset containing both the A1 motorway and the bike path.

# %%
union_pr = UnionProcess(inputs=[iraq_roads_a1, iraq_bikepaths])
union_pr.compute()
print union_pr.output.uri
union_pr.output.data
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/b9b482f1-b320-41b1-92a2-db71f64f797f/b9b482f1-b320-41b1-92a2-db71f64f797f.json
#     bridge                                           geometry  maxspeed name  \
# 4        0  (LINESTRING (44.3001547 33.4038565, 44.301367 ...         0
# 8        0  (LINESTRING (44.3074825 33.3936365, 44.3066993...         0
# 14       0  (LINESTRING (44.3172727 33.3805368, 44.3154935...         0
# 15       0  (LINESTRING (44.3073645 33.3935827, 44.3115358...         0
# 41       0  (LINESTRING (44.3145438 33.3837802, 44.3150089...         0
# 0        0  (LINESTRING (44.3087191 33.2924177, 44.3081596...         0
#
#     oneway     osm_id  ref  tunnel      type
# 4        1    4076793   A1       0  motorway
# 8        1    4076792   A1       0  motorway
# 14       1    4234529   A1       0  motorway
# 15       1    4234530   A1       0  motorway
# 41       1  233575082   A1       0  motorway
# 0        1    4061247  A86       0  bikepath

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

roadstyle = lambda x: {'color': 'red', 'line_opacity': 0.1, 'line_weight':15}
bikestyle = lambda y: {'color': 'green', 'line_opacity': 0.1, 'line_weight':10}
unionstyle = lambda z: {'color': 'blue', 'line_opacity': 0.1, 'line_weight':5}

bikepaths = folium.features.GeoJson(iraq_bikepaths.data.to_json(), style_function=bikestyle, name='Bikepaths')
roads = folium.features.GeoJson(iraq_roads_a1.data.to_json(), style_function=roadstyle, name='Motorways')
union = folium.features.GeoJson(union_pr.output.data.to_json(), style_function=unionstyle, name='Union')

iraq_map.add_children(roads)
iraq_map.add_children(bikepaths)
iraq_map.add_children(union)
folium.LayerControl().add_to(iraq_map)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:15: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Centroid
#
# Find the centroid of each district in Baghdad.

# %%
centroid_pr = CentroidProcess(inputs=[baghdad_alldistricts])
centroid_pr.compute()
print centroid_pr.output.uri
centroid_pr.output.data[0:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/1d6884b3-2a4e-4ab7-82e5-e1f1388f95e9/1d6884b3-2a4e-4ab7-82e5-e1f1388f95e9.json
#    DID      DNAME  NID                              NNAME  \
# 0    7    Mansour   74      Baghdad International Airport
# 1    4    Karadah   46                          Zafriniya
# 2    1  Adhamiyah   25                           Rashdiya
# 3    2     Thawra   28                        Thawra City
# 4    3   7 Nissan   33  Habibiyah, Dor Al-Umal, Baladiyat
#
#                                       geometry                       id
# 0  POINT (44.24203388449014 33.29812003683929)  baghdad_neighborhoods.1
# 1   POINT (44.50798725653361 33.2531754261915)  baghdad_neighborhoods.2
# 2  POINT (44.36887089157968 33.41849950580148)  baghdad_neighborhoods.3
# 3  POINT (44.45881769675281 33.38902692655981)  baghdad_neighborhoods.4
# 4  POINT (44.46994088448522 33.34038133876043)  baghdad_neighborhoods.5

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=11,
                  tiles='cartodbpositron')

linestyle = lambda x: {'color': 'red'}
districts = folium.features.GeoJson(baghdad_alldistricts.data.to_json())
centroids = folium.features.GeoJson(centroid_pr.output.data.to_json())

iraq_map.add_children(districts)
iraq_map.add_children(centroids)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Equals
#
# Find the features in the allroads input that are the same as the features in the motorways input

# %%
equals_pr = EqualsProcess(inputs=[iraq_allroads, iraq_roads_a1])
equals_pr.compute()
print equals_pr.output.uri
equals_pr.output.data[0:5]
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/db28cbbc-d977-4180-af62-588cb6592202/db28cbbc-d977-4180-af62-588cb6592202.json
#     bridge                                           geometry  maxspeed name  \
# 4        0  (LINESTRING (44.3001547 33.4038565, 44.301367 ...         0
# 8        0  (LINESTRING (44.3074825 33.3936365, 44.3066993...         0
# 15       0  (LINESTRING (44.3073645 33.3935827, 44.3115358...         0
# 41       0  (LINESTRING (44.3145438 33.3837802, 44.3150089...         0
#
#     oneway     osm_id ref  tunnel      type
# 4        1    4076793  A1       0  motorway
# 8        1    4076792  A1       0  motorway
# 15       1    4234530  A1       0  motorway
# 41       1  233575082  A1       0  motorway

# %%
iraq_map = folium.Map([33.35, 44.30871909999998],
                  zoom_start=12,
                  tiles='cartodbpositron')

roadstyle = lambda x: {'color': 'red', 'line_opacity': 0.1, 'line_weight':15}
motorwaystyle = lambda y: {'color': 'green', 'line_opacity': 0.1, 'line_weight':10}
equalstyle = lambda z: {'color': 'blue', 'line_opacity': 0.1, 'line_weight':5}

allroads = folium.features.GeoJson(iraq_allroads.data.to_json(), style_function=roadstyle, name='All Roads')
motorways = folium.features.GeoJson(iraq_roads_a1.data.to_json(), style_function=motorwaystyle, name='Motorways')
equal = folium.features.GeoJson(equals_pr.output.data.to_json(), style_function=equalstyle, name='Equal')

iraq_map.add_children(allroads)
iraq_map.add_children(motorways)
iraq_map.add_children(equal)
folium.LayerControl().add_to(iraq_map)
iraq_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:15: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Zonal Statistics
#
# Calculate global temperature statistics (mean, min, max, etc) within two vector polygons

# %%
# Two polygons
polygonio = FeatureIO(features=[
        {"geometry": {"type": "Polygon", "coordinates": [
                    [[-120,20], [-120,40], [-70,40], [-70,20], [-120,20]]
                ]}, "properties":{"id": "North polygon"}},
        {"geometry": {"type": "Polygon", "coordinates": [
                    [[120,-20], [120,-40], [70,-40], [70,-20], [120,-20]]
                ]}, "properties":{"id": "South polygon"}}        
    ])
zonal_pr = ZonalStatsProcess(inputs=[globaltemp, polygonio])
zonal_pr.compute()
print zonal_pr.output.uri
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/tests/data/output/3da29f86-db5d-4ec2-b763-12a038aefab0/3da29f86-db5d-4ec2-b763-12a038aefab0.json

# %%
zonal_pr.output.data
# Out:
#    count                                           geometry             id  \
# 0   1000  POLYGON ((-120 20, -120 40, -70 40, -70 20, -1...  North polygon
# 1   1000  POLYGON ((120 -20, 120 -40, 70 -40, 70 -20, 12...  South polygon
#
#        max       mean   median      min      stddev         sum
# 0  29879.0  28286.520  28291.0  25939.0  941.351625  28286520.0
# 1  30986.0  29433.919  29418.0  28627.0  438.157292  29433919.0

# %%
world_map = folium.Map([0,0],
                  zoom_start=2,
                  tiles='cartodbpositron')

polys = folium.features.GeoJson(polygonio.data.to_json(), name='Polygon')
temparray = np.array(globaltemp.read().GetRasterBand(1).ReadAsArray())
overlay = ImageOverlay(temparray, [[-90.0,-180.0],[90.0,180.0]], mercator_project=True, control=True)
overlay.layer_name = 'Air Temp'

world_map.add_children(overlay)
world_map.add_children(polys)

folium.LayerControl().add_to(world_map)
world_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Subset Raster
#
# Create a new global temperature image only containing the area inside a polygon.

# %%
# One polygon
polygonio1 = FeatureIO(features=[
        {"geometry": {"type": "Polygon", "coordinates": [
                    [[-120,20], [-120,40], [-70,40], [-70,20], [-120,20]]
                ]}, "properties":{"id": "North polygon"}}       
    ])
subset_pr = SubsetProcess(inputs=[globaltemp, polygonio1])
subset_pr.compute()

# %%
world_map = folium.Map([0,0],
                  zoom_start=2,
                  tiles='cartodbpositron')

polys = folium.features.GeoJson(polygonio1.data.to_json(), name='Polygon')
world_map.add_children(polys, name="Polygons")

subset_array = np.array(subset_pr.output.read().GetRasterBand(1).ReadAsArray())
overlay = ImageOverlay(subset_array, [[20.0,-120.0],[40.0,-70.0]], mercator_project=True, control=True)
overlay.layer_name = 'Air Temp Subset'

world_map.add_children(overlay)
folium.LayerControl().add_to(world_map)

world_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Raster Math
#
# Add global temperature and precipitation image data together then divide by 2.

# %%
math_pr = RasterMathProcess(inputs=[globaltemp, globalprecip], calc='(A+B)/2')
math_pr.compute()
# Out:
# /Users/andrengyyen/Documents/Epidemico/GUMBO/gaia/gaia/geo/gdal_functions.py:407: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   nodatavalues == 1, band_vals == nodata_vals[i])

# %%
world_map = folium.Map([0,0],
                  zoom_start=2,
                  tiles='cartodbpositron')

temparray = np.array(globaltemp.read().GetRasterBand(1).ReadAsArray())
preciparray = np.array(globalprecip.read().GetRasterBand(1).ReadAsArray())
matharray = np.array(math_pr.output.read().GetRasterBand(1).ReadAsArray())

bounds = [[-90,-180],[90,180]]

overlay_temp = ImageOverlay(temparray, bounds, mercator_project=True, control=True)
overlay_temp.layer_name = 'Air Temperature'
overlay_precip = ImageOverlay(preciparray, bounds, mercator_project=True, control=True)
overlay_precip.layer_name = 'Precipitation'
overlay_math = ImageOverlay(matharray, bounds, mercator_project=True, control=True)
overlay_math.layer_name = '(Temp * Precipitation)/2'    
    
for array in (overlay_temp, overlay_precip, overlay_math):
    world_map.add_children(array)
    
folium.LayerControl().add_to(world_map)    
world_map
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Merge Multiple Raster Datasets Into One Multi-band Raster Dataset

# %%
# Raster inputs.
inputs = [satellite1, satellite2, satellite3]

# Merge.
merge_pr = MergeProcess(inputs=inputs)
merge_pr.compute()

# Test.
import numpy as np
for i in range(len(inputs)):
    print np.array_equal(merge_pr.output.read().ReadAsArray()[i],inputs[i].read().ReadAsArray())
# Out:
# True
# True
# True
