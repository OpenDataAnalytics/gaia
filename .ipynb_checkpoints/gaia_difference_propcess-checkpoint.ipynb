# %%
from geopandas import GeoDataFrame, GeoSeries

# %%
import pandas as pd

# %%
iraq_hospitals = GeoDataFrame.from_file('/Users/essamjoubori1/epidemico/gaia/tests/data/geoprocess/iraq_hospitals.geojson')

# %%
iraq_hospitals[0:4]
# Out:
#    fid                       geometry                         name     osm_id  \
# 0   28  POINT (44.3781274 33.3451792)  جامعة بغداد -- كلية الطب آل   94298797
# 1   32  POINT (43.1142917 36.3579936)            المستشفى الجمهوري  100530934
# 2   39  POINT (43.1683962 36.3834541)               مستشفى الخنساء  256791649
# 3   58  POINT (44.3815083 32.0206296)                               502313229
#
#               timestamp      type
# 0  2012-07-20T11:15:39Z  hospital
# 1  2008-05-16T10:49:22Z  hospital
# 2  2008-04-26T21:15:25Z  hospital
# 3  2009-09-19T19:43:15Z  hospital

# %%
# %matplotlib inline
iraq_hospitals.plot()

# %%
baghdad_districts = GeoDataFrame.from_file('/Users/essamjoubori1/epidemico/gaia/tests/data/geoprocess/baghdad_districts.geojson')

# %%
# %matplotlib inline
baghdad_districts.plot()

# %%
difference = iraq_hospitals[iraq_hospitals.geometry.intersects(
            baghdad_districts.geometry.unary_union) == False]

# %%
# %matplotlib inline
difference.plot()
